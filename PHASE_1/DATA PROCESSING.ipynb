# %%
import pandas as pd

# %%
d=pd.read_csv("pbl.csv")

# %%
d
# Out:
#         userId  movieId  rating   timestamp                     movie_title  \
# 0            1        1     4.0   964982703                Toy Story (1995)
# 1            1        3     4.0   964981247         Grumpier Old Men (1995)
# 2            1        6     4.0   964982224                     Heat (1995)
# 3            1       47     5.0   964983815     Seven (a.k.a. Se7en) (1995)
# 4            1       50     5.0   964982931      Usual Suspects, The (1995)
# ...        ...      ...     ...         ...                             ...
# 100245     610   166534     4.0  1493848402                    Split (2017)
# 100246     610   168248     5.0  1493850091   John Wick: Chapter Two (2017)
# 100247     610   168250     5.0  1494273047                  Get Out (2017)
# 100248     610   168252     5.0  1493846352                    Logan (2017)
# 100249     610   170875     3.0  1493846415  The Fate of the Furious (2017)
#
#                                              genres
# 0       Adventure|Animation|Children|Comedy|Fantasy
# 1                                    Comedy|Romance
# 2                             Action|Crime|Thriller
# 3                                  Mystery|Thriller
# 4                            Crime|Mystery|Thriller
# ...                                             ...
# 100245                        Drama|Horror|Thriller
# 100246                        Action|Crime|Thriller
# 100247                                       Horror
# 100248                                Action|Sci-Fi
# 100249                  Action|Crime|Drama|Thriller
#
# [100250 rows x 6 columns]

# %%
df=pd.DataFrame(d)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100250 entries, 0 to 100249
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   userId       100250 non-null  int64
#  1   movieId      100250 non-null  int64
#  2   rating       100250 non-null  float64
#  3   timestamp    100250 non-null  int64
#  4   movie_title  100250 non-null  object
#  5   genres       100250 non-null  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 4.6+ MB

# %%
df.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100250.000000  100250.000000  100250.000000  1.002500e+05
# mean      325.973566   19122.092489       3.501606  1.204787e+09
# std       182.520792   35260.139972       1.041904  2.161079e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1198.000000       3.000000  1.014822e+09
# 50%       325.000000    2973.000000       3.500000  1.182911e+09
# 75%       477.000000    7458.000000       4.000000  1.435944e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
df.isnull().sum()
# Out:
# userId         0
# movieId        0
# rating         0
# timestamp      0
# movie_title    0
# genres         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.size
# Out:
# 601500

# %%
df.shape
# Out:
# (100250, 6)

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"], unit="s")

# %%
df["hour"] = df["timestamp"].dt.hour
df["day_of_week"] = df["timestamp"].dt.dayofweek

# %%
df
# Out:
#         userId  movieId  rating           timestamp  \
# 0            1        1     4.0 2000-07-30 18:45:03
# 1            1        3     4.0 2000-07-30 18:20:47
# 2            1        6     4.0 2000-07-30 18:37:04
# 3            1       47     5.0 2000-07-30 19:03:35
# 4            1       50     5.0 2000-07-30 18:48:51
# ...        ...      ...     ...                 ...
# 100245     610   166534     4.0 2017-05-03 21:53:22
# 100246     610   168248     5.0 2017-05-03 22:21:31
# 100247     610   168250     5.0 2017-05-08 19:50:47
# 100248     610   168252     5.0 2017-05-03 21:19:12
# 100249     610   170875     3.0 2017-05-03 21:20:15
#
#                            movie_title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# 3          Seven (a.k.a. Se7en) (1995)
# 4           Usual Suspects, The (1995)
# ...                                ...
# 100245                    Split (2017)
# 100246   John Wick: Chapter Two (2017)
# 100247                  Get Out (2017)
# 100248                    Logan (2017)
# 100249  The Fate of the Furious (2017)
#
#                                              genres  hour  day_of_week
# 0       Adventure|Animation|Children|Comedy|Fantasy    18            6
# 1                                    Comedy|Romance    18            6
# 2                             Action|Crime|Thriller    18            6
# 3                                  Mystery|Thriller    19            6
# 4                            Crime|Mystery|Thriller    18            6
# ...                                             ...   ...          ...
# 100245                        Drama|Horror|Thriller    21            2
# 100246                        Action|Crime|Thriller    22            2
# 100247                                       Horror    19            0
# 100248                                Action|Sci-Fi    21            2
# 100249                  Action|Crime|Drama|Thriller    21            2
#
# [100250 rows x 8 columns]

# %%
movie_popularity = df.groupby("movieId")["rating"].count()
df["movie_rating_count"] = df["movieId"].map(movie_popularity)

# %%
df
# Out:
#         userId  movieId  rating           timestamp  \
# 0            1        1     4.0 2000-07-30 18:45:03
# 1            1        3     4.0 2000-07-30 18:20:47
# 2            1        6     4.0 2000-07-30 18:37:04
# 3            1       47     5.0 2000-07-30 19:03:35
# 4            1       50     5.0 2000-07-30 18:48:51
# ...        ...      ...     ...                 ...
# 100245     610   166534     4.0 2017-05-03 21:53:22
# 100246     610   168248     5.0 2017-05-03 22:21:31
# 100247     610   168250     5.0 2017-05-08 19:50:47
# 100248     610   168252     5.0 2017-05-03 21:19:12
# 100249     610   170875     3.0 2017-05-03 21:20:15
#
#                            movie_title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# 3          Seven (a.k.a. Se7en) (1995)
# 4           Usual Suspects, The (1995)
# ...                                ...
# 100245                    Split (2017)
# 100246   John Wick: Chapter Two (2017)
# 100247                  Get Out (2017)
# 100248                    Logan (2017)
# 100249  The Fate of the Furious (2017)
#
#                                              genres  hour  day_of_week  \
# 0       Adventure|Animation|Children|Comedy|Fantasy    18            6
# 1                                    Comedy|Romance    18            6
# 2                             Action|Crime|Thriller    18            6
# 3                                  Mystery|Thriller    19            6
# 4                            Crime|Mystery|Thriller    18            6
# ...                                             ...   ...          ...
# 100245                        Drama|Horror|Thriller    21            2
# 100246                        Action|Crime|Thriller    22            2
# 100247                                       Horror    19            0
# 100248                                Action|Sci-Fi    21            2
# 100249                  Action|Crime|Drama|Thriller    21            2
#
#         movie_rating_count
# 0                      215
# 1                       52
# 2                      102
# 3                      203
# 4                      204
# ...                    ...
# 100245                   6
# 100246                   7
# 100247                  15
# 100248                  25
# 100249                   3
#
# [100250 rows x 9 columns]

# %%
user_activity = df.groupby("userId")["rating"].count()
df["user_rating_count"] = df["userId"].map(user_activity)

# %%
df
# Out:
#         userId  movieId  rating           timestamp  \
# 0            1        1     4.0 2000-07-30 18:45:03
# 1            1        3     4.0 2000-07-30 18:20:47
# 2            1        6     4.0 2000-07-30 18:37:04
# 3            1       47     5.0 2000-07-30 19:03:35
# 4            1       50     5.0 2000-07-30 18:48:51
# ...        ...      ...     ...                 ...
# 100245     610   166534     4.0 2017-05-03 21:53:22
# 100246     610   168248     5.0 2017-05-03 22:21:31
# 100247     610   168250     5.0 2017-05-08 19:50:47
# 100248     610   168252     5.0 2017-05-03 21:19:12
# 100249     610   170875     3.0 2017-05-03 21:20:15
#
#                            movie_title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# 3          Seven (a.k.a. Se7en) (1995)
# 4           Usual Suspects, The (1995)
# ...                                ...
# 100245                    Split (2017)
# 100246   John Wick: Chapter Two (2017)
# 100247                  Get Out (2017)
# 100248                    Logan (2017)
# 100249  The Fate of the Furious (2017)
#
#                                              genres  hour  day_of_week  \
# 0       Adventure|Animation|Children|Comedy|Fantasy    18            6
# 1                                    Comedy|Romance    18            6
# 2                             Action|Crime|Thriller    18            6
# 3                                  Mystery|Thriller    19            6
# 4                            Crime|Mystery|Thriller    18            6
# ...                                             ...   ...          ...
# 100245                        Drama|Horror|Thriller    21            2
# 100246                        Action|Crime|Thriller    22            2
# 100247                                       Horror    19            0
# 100248                                Action|Sci-Fi    21            2
# 100249                  Action|Crime|Drama|Thriller    21            2
#
#         movie_rating_count  user_rating_count
# 0                      215                232
# 1                       52                232
# 2                      102                232
# 3                      203                232
# 4                      204                232
# ...                    ...                ...
# 100245                   6               1277
# 100246                   7               1277
# 100247                  15               1277
# 100248                  25               1277
# 100249                   3               1277
#
# [100250 rows x 10 columns]

# %%
movie_avg = df.groupby("movieId")["rating"].mean()
df["movie_avg_rating"] = df["movieId"].map(movie_avg)

# %%
df
# Out:
#         userId  movieId  rating           timestamp  \
# 0            1        1     4.0 2000-07-30 18:45:03
# 1            1        3     4.0 2000-07-30 18:20:47
# 2            1        6     4.0 2000-07-30 18:37:04
# 3            1       47     5.0 2000-07-30 19:03:35
# 4            1       50     5.0 2000-07-30 18:48:51
# ...        ...      ...     ...                 ...
# 100245     610   166534     4.0 2017-05-03 21:53:22
# 100246     610   168248     5.0 2017-05-03 22:21:31
# 100247     610   168250     5.0 2017-05-08 19:50:47
# 100248     610   168252     5.0 2017-05-03 21:19:12
# 100249     610   170875     3.0 2017-05-03 21:20:15
#
#                            movie_title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# 3          Seven (a.k.a. Se7en) (1995)
# 4           Usual Suspects, The (1995)
# ...                                ...
# 100245                    Split (2017)
# 100246   John Wick: Chapter Two (2017)
# 100247                  Get Out (2017)
# 100248                    Logan (2017)
# 100249  The Fate of the Furious (2017)
#
#                                              genres  hour  day_of_week  \
# 0       Adventure|Animation|Children|Comedy|Fantasy    18            6
# 1                                    Comedy|Romance    18            6
# 2                             Action|Crime|Thriller    18            6
# 3                                  Mystery|Thriller    19            6
# 4                            Crime|Mystery|Thriller    18            6
# ...                                             ...   ...          ...
# 100245                        Drama|Horror|Thriller    21            2
# 100246                        Action|Crime|Thriller    22            2
# 100247                                       Horror    19            0
# 100248                                Action|Sci-Fi    21            2
# 100249                  Action|Crime|Drama|Thriller    21            2
#
#         movie_rating_count  user_rating_count  movie_avg_rating
# 0                      215                232          3.920930
# 1                       52                232          3.259615
# 2                      102                232          3.946078
# 3                      203                232          3.975369
# 4                      204                232          4.237745
# ...                    ...                ...               ...
# 100245                   6               1277          3.333333
# 100246                   7               1277          4.142857
# 100247                  15               1277          3.633333
# 100248                  25               1277          4.280000
# 100249                   3               1277          2.333333
#
# [100250 rows x 11 columns]

# %%
import numpy as np

# %%
df["preference"] = np.where(df["rating"] >= 3, 1, 0)

# %%
df
# Out:
#         userId  movieId  rating           timestamp  \
# 0            1        1     4.0 2000-07-30 18:45:03
# 1            1        3     4.0 2000-07-30 18:20:47
# 2            1        6     4.0 2000-07-30 18:37:04
# 3            1       47     5.0 2000-07-30 19:03:35
# 4            1       50     5.0 2000-07-30 18:48:51
# ...        ...      ...     ...                 ...
# 100245     610   166534     4.0 2017-05-03 21:53:22
# 100246     610   168248     5.0 2017-05-03 22:21:31
# 100247     610   168250     5.0 2017-05-08 19:50:47
# 100248     610   168252     5.0 2017-05-03 21:19:12
# 100249     610   170875     3.0 2017-05-03 21:20:15
#
#                            movie_title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# 3          Seven (a.k.a. Se7en) (1995)
# 4           Usual Suspects, The (1995)
# ...                                ...
# 100245                    Split (2017)
# 100246   John Wick: Chapter Two (2017)
# 100247                  Get Out (2017)
# 100248                    Logan (2017)
# 100249  The Fate of the Furious (2017)
#
#                                              genres  hour  day_of_week  \
# 0       Adventure|Animation|Children|Comedy|Fantasy    18            6
# 1                                    Comedy|Romance    18            6
# 2                             Action|Crime|Thriller    18            6
# 3                                  Mystery|Thriller    19            6
# 4                            Crime|Mystery|Thriller    18            6
# ...                                             ...   ...          ...
# 100245                        Drama|Horror|Thriller    21            2
# 100246                        Action|Crime|Thriller    22            2
# 100247                                       Horror    19            0
# 100248                                Action|Sci-Fi    21            2
# 100249                  Action|Crime|Drama|Thriller    21            2
#
#         movie_rating_count  user_rating_count  movie_avg_rating  preference
# 0                      215                232          3.920930           1
# 1                       52                232          3.259615           1
# 2                      102                232          3.946078           1
# 3                      203                232          3.975369           1
# 4                      204                232          4.237745           1
# ...                    ...                ...               ...         ...
# 100245                   6               1277          3.333333           1
# 100246                   7               1277          4.142857           1
# 100247                  15               1277          3.633333           1
# 100248                  25               1277          4.280000           1
# 100249                   3               1277          2.333333           1
#
# [100250 rows x 12 columns]

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\acer\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\acer\anaconda3\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\acer\anaconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\acer\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\acer\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

cols_to_scale = [ "movie_rating_count", 
                 "user_rating_count", "movie_avg_rating"]

df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
df["userId_encoded"] = df["userId"].astype("category").cat.codes
df["movieId_encoded"] = df["movieId"].astype("category").cat.codes

# %%
df
# Out:
#         userId  movieId  rating           timestamp  \
# 0            1        1     4.0 2000-07-30 18:45:03
# 1            1        3     4.0 2000-07-30 18:20:47
# 2            1        6     4.0 2000-07-30 18:37:04
# 3            1       47     5.0 2000-07-30 19:03:35
# 4            1       50     5.0 2000-07-30 18:48:51
# ...        ...      ...     ...                 ...
# 100245     610   166534     4.0 2017-05-03 21:53:22
# 100246     610   168248     5.0 2017-05-03 22:21:31
# 100247     610   168250     5.0 2017-05-08 19:50:47
# 100248     610   168252     5.0 2017-05-03 21:19:12
# 100249     610   170875     3.0 2017-05-03 21:20:15
#
#                            movie_title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# 3          Seven (a.k.a. Se7en) (1995)
# 4           Usual Suspects, The (1995)
# ...                                ...
# 100245                    Split (2017)
# 100246   John Wick: Chapter Two (2017)
# 100247                  Get Out (2017)
# 100248                    Logan (2017)
# 100249  The Fate of the Furious (2017)
#
#                                              genres  hour  day_of_week  \
# 0       Adventure|Animation|Children|Comedy|Fantasy    18            6
# 1                                    Comedy|Romance    18            6
# 2                             Action|Crime|Thriller    18            6
# 3                                  Mystery|Thriller    19            6
# 4                            Crime|Mystery|Thriller    18            6
# ...                                             ...   ...          ...
# 100245                        Drama|Horror|Thriller    21            2
# 100246                        Action|Crime|Thriller    22            2
# 100247                                       Horror    19            0
# 100248                                Action|Sci-Fi    21            2
# 100249                  Action|Crime|Drama|Thriller    21            2
#
#         movie_rating_count  user_rating_count  movie_avg_rating  preference  \
# 0                 0.652439           0.079401          0.760207           1
# 1                 0.155488           0.079401          0.613248           1
# 2                 0.307927           0.079401          0.765795           1
# 3                 0.615854           0.079401          0.772304           1
# 4                 0.618902           0.079401          0.830610           1
# ...                    ...                ...               ...         ...
# 100245            0.015244           0.470787          0.629630           1
# 100246            0.018293           0.470787          0.809524           1
# 100247            0.042683           0.470787          0.696296           1
# 100248            0.073171           0.470787          0.840000           1
# 100249            0.006098           0.470787          0.407407           1
#
#         userId_encoded  movieId_encoded
# 0                    0                0
# 1                    0                2
# 2                    0                5
# 3                    0               43
# 4                    0               46
# ...                ...              ...
# 100245             609             9133
# 100246             609             9160
# 100247             609             9161
# 100248             609             9162
# 100249             609             9202
#
# [100250 rows x 14 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SequentialFeatureSelector

# %%
X = df.drop(columns=['preference', 'movie_title', 'timestamp','genres','rating','userId','movieId'], errors='ignore')
y = df['preference']

# %%
model = LogisticRegression(max_iter=1000)

# %%
sfs = SequentialFeatureSelector(
    model,
    n_features_to_select=5,
    direction='forward',
    cv=3   
)

# %%
sfs.fit(X, y)
# Out:
# SequentialFeatureSelector(cv=3, estimator=LogisticRegression(max_iter=1000),
#                           n_features_to_select=5)

# %%
selected_features = X.columns[sfs.get_support()]

print(selected_features)
# Out:
# Index(['hour', 'movie_rating_count', 'user_rating_count', 'movie_avg_rating',
#        'movieId_encoded'],
#       dtype='object')
